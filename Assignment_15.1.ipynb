# %%
import pandas as pd
import numpy as np
import sqlite3 as db
import matplotlib.pyplot as plt

col_Names1 = ['Indicator', 'PUBLISH_STATES', 'Year', 'WHO_region', 'World_Bank_income_group', 'Country', 'Sex', 
 'Display_Value','NumericValue', 'Low', 'High', 'Comments']

col_Names2 = ['STATION', 'STATION_NAME', 'DATE', 'PRCP','SNWD', 'SNOW', 'TMAX','TMIN', 'WDFG','PGTM','WSFG',
'WT09', 'WT07' , 'WT01', 'WT06', 'WT05', 'WT04', 'WT16','WT08','WT18','WT03']

df1 = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
print('printing df1 columns')
print(df1.columns.tolist())

df1.rename(columns={'Indicator': 'Indicator_ID','PUBLISH STATES': 'PUBLICATION STATUS','WHO region': 'WHO Region' }, inplace=True)
print('After renaming columns, printing df1 columns')
print(df1.columns.tolist())

df2 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
print('printing df2 columns')
print(df2.columns.tolist())
          
df1.info()
df2.info()

#Create a sql db from adult dataset and name it sqladb
con = db.connect("RawData_example.db3")
df1.to_sql("WBANK_INFO_TABLE", con, if_exists='replace', index=False) 

df2.to_sql("BERLIN_WEATHER", con, if_exists='replace', index=False) 

#Select 10 records from the adult sqladb
df10 = pd.read_sql_query("SELECT * FROM WBANK_INFO_TABLE LIMIT 10",con)
print(df10)

#Select 10 records from the adult sqladb
df20 = pd.read_sql_query("SELECT * FROM BERLIN_WEATHER LIMIT 20",con)
print(df20)
# Out:
# printing df1 columns
# ['Indicator', 'PUBLISH STATES', 'Year', 'WHO region', 'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric', 'Low', 'High', 'Comments']
# After renaming columns, printing df1 columns
# ['Indicator_ID', 'PUBLICATION STATUS', 'Year', 'WHO Region', 'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric', 'Low', 'High', 'Comments']
# printing df2 columns
# ['STATION', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX', 'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06', 'WT05', 'WT04', 'WT16', 'WT08', 'WT18', 'WT03']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator_ID               4656 non-null object
# PUBLICATION STATUS         4656 non-null object
# Year                       4656 non-null int64
# WHO Region                 4656 non-null object
# World Bank income group    4656 non-null object
# ...
